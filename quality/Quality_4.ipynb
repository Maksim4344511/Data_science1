# %%
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
import numpy as np

# %%
df = pd.read_csv('./assignments_from_pool_Quality_4.tsv', sep="\t")

# %%
df = df.drop(columns=['GOLDEN:ad', 'GOLDEN:not_ad', 'GOLDEN:ban_insult_hard', 'GOLDEN:ban_shock_content', 'GOLDEN:ban_shock_content',
'HINT:text', 'HINT:default_language'])

# %%
df = df.fillna(0)
def f(row):
    if row['OUTPUT:ad'] == 'yes':
        val = 'ad'
    elif row['OUTPUT:not_ad'] != 0:
        val = 'not_ad'
    elif row['OUTPUT:ban_insult_hard'] != 0:
        val = 'ban_insult_hard'
    elif row['OUTPUT:ban_shock_content'] != 0:
        val = 'ban_shock_content'    
    else:
        val = ' '
    return val

df['OUTPUT:label'] = df.apply(f, axis=1)

# %%
df.head()
# Out:
#          INPUT:label                                      INPUT:comment  \
# 0                 ad  Центр Скупки. Центр Скупки предоставляет услуг...
# 1  ban_shock_content  Убили котика у ТЕЦ на Бирюлево 3к2. Сегодня  н...
# 2             not_ad  Увидел, как в Кашкадане на месте озера возится...
# 3    ban_insult_hard  Простите но наши врачище! бараны!!! -тупые в б...
# 4             not_ad  Татьянка Борисова рассказывает, что на Коровин...
#
#    INPUT:task-id OUTPUT:ad OUTPUT:not_ad OUTPUT:ban_insult_hard  \
# 0             70       yes             0                      0
# 1            366        no             0                      0
# 2            489        no          True                      0
# 3            294        no             0                   True
# 4            446        no          True                      0
#
#   OUTPUT:ban_shock_content              ASSIGNMENT:worker_id  \
# 0                        0  0186400b77dcfad3fd78b2c08981ebd8
# 1                     True  0186400b77dcfad3fd78b2c08981ebd8
# 2                        0  0186400b77dcfad3fd78b2c08981ebd8
# 3                        0  0186400b77dcfad3fd78b2c08981ebd8
# 4                        0  0186400b77dcfad3fd78b2c08981ebd8
#
#         OUTPUT:label
# 0                 ad
# 1  ban_shock_content
# 2             not_ad
# 3    ban_insult_hard
# 4             not_ad

# %%
df = df.drop(columns=['OUTPUT:ad', 'OUTPUT:not_ad', 'OUTPUT:ban_insult_hard', 'OUTPUT:ban_shock_content'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1953 entries, 0 to 1952
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   INPUT:label           1953 non-null   object
#  1   INPUT:comment         1953 non-null   object
#  2   INPUT:task-id         1953 non-null   int64
#  3   ASSIGNMENT:worker_id  1953 non-null   object
#  4   OUTPUT:label          1953 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 76.4+ KB

# %%
#сохранения в tsv
df.to_csv('Quality_4.tsv', sep="\t", index=False)

# %%
df[df['INPUT:label'] == df['OUTPUT:label']].count()[0]
# Out:
# 1755

# %%
df[df['INPUT:label'] != df['OUTPUT:label']].count()[0]
# Out:
# 198

# %%
# 10% неправильных ответов
df[df['INPUT:label'] != df['OUTPUT:label']].count()[0]/df.count()[0]
# Out:
# 0.10138248847926268

# %%
# 
_, axes = plt.subplots(1, sharey=True, figsize=(10,5))


sns.countplot(x='INPUT:label', hue='OUTPUT:label', data=df);

# %%
df[(df['INPUT:label'] != df['OUTPUT:label']) & (df['INPUT:label'] == 'ad')]
# Out:
#      INPUT:label                                      INPUT:comment  \
# 7             ad  Дизайн проект. Дизайн проект состоит из: 1. Ан...
# 99            ad  Ленинградская область. Эльбрус Удаление деревь...
# 154           ad  ЖК "Джаз". Вторая очередь. Скоро.. Началось ст...
# 233           ad  Выберете ли Вы в качестве подарка - Фотомозаик...
# 250           ad  Где заказываете крауд-ссылки?. Поделитесь, кто...
# 298           ad  Road to Jedi. Иллюминаты захватили мир? Попроб...
# 306           ad  Road to Jedi. Иллюминаты захватили мир? Попроб...
# 330           ad  Где заказываете крауд-ссылки?. Поделитесь, кто...
# 693           ad  Дизайн проект. Дизайн проект состоит из: 1. Ан...
# 858           ad  Пост от 24.05. Почему нас долго не было, спрос...
# 1129          ad  "Black Gryphon" Studio Shutterstock. https://w...
# 1207          ad  Внимание. Продаю книги в электронном виде по 5...
# 1339          ad  экскурсии  вторник и четверг 12:15, 13:30, 14:...
# 1387          ad  Снять жилье. Гудзон хостел - это уютная и недо...
# 1415          ad  Собака напала на велосипедистку. Велосипедисты...
# 1417          ad  Телефон. Продаю телефон https://www.avito.ru/m...
# 1483          ad  Автомойка в Коптево. Дорогие соседи, в нашем р...
# 1507          ad  Нужны отзывы!!. Кто заказываю тут окна, подели...
# 1551          ad  Приглашаем к нам. Здравствуйте, уважаемые сосе...
# 1558          ad  Регулярные рейсы Воронеж-Москва-Воронеж. Ежедн...
# 1591          ad  Нужны отзывы!!. Кто заказываю тут окна, подели...
# 1739          ad  Бесплатно помогаю в недвижимости. Привет!) Рад...
# 1849          ad  Автошкола «Ганг Люкс» продолжает набор групп!....
# 1897          ad  Друзья🙃Это ребята, у которых все повестки Боев...
#
#       INPUT:task-id              ASSIGNMENT:worker_id       OUTPUT:label
# 7               189  55c8ccb7c8eec80f7c17e74f36fb5453             not_ad
# 99                6  7d36240662e27b95b61575138e1088a2             not_ad
# 154             198  0186400b77dcfad3fd78b2c08981ebd8             not_ad
# 233             188  d6bab13aab22980c61e53025a05ea2e0             not_ad
# 250              84  0186400b77dcfad3fd78b2c08981ebd8             not_ad
# 298             123  de03cc3542ba3f30548168ef644c4de8    ban_insult_hard
# 306             123  0186400b77dcfad3fd78b2c08981ebd8             not_ad
# 330              84  6a9db0bac8daa328d10d09b73e2fcfa7             not_ad
# 693             189  37381e101d96c03972d9413100c9a652             not_ad
# 858             151  6a9db0bac8daa328d10d09b73e2fcfa7             not_ad
# 1129             14  a90953f93f3f8a773f97cbaef9c71128             not_ad
# 1207             68  a90953f93f3f8a773f97cbaef9c71128             not_ad
# 1339              0  0d4b5165b310a9cc2702ba783740e315             not_ad
# 1387             91  69c70b4e3f079a20c0c6a318d326e272             not_ad
# 1415            134  54a9906865752e6bc58710ea757c260e  ban_shock_content
# 1417             46  54a9906865752e6bc58710ea757c260e             not_ad
# 1483            135  d6bab13aab22980c61e53025a05ea2e0             not_ad
# 1507             17  fc7d784b52807ef5d0e54a9778a2a75c             not_ad
# 1551            178  69c70b4e3f079a20c0c6a318d326e272             not_ad
# 1558            136  fc7d784b52807ef5d0e54a9778a2a75c             not_ad
# 1591             17  2c32e860c51d80bc051f6d49e8acd4fe             not_ad
# 1739            113  e1a1d9efc8ea1d1bbf15994095578a47             not_ad
# 1849            156  857fb39e49d8c270f2fe358ba7bf9804  ban_shock_content
# 1897            106  d309d2358f0d57a4fa7a6f645f1cb350             not_ad
