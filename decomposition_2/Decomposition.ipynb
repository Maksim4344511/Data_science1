# %%
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
import numpy as np
from pandas import read_excel

# %%
df = pd.read_csv('./Decomp_1.tsv', sep="\t")

# %%
df = df.drop(columns=['GOLDEN:result', 'HINT:text', 'HINT:default_language'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754 entries, 0 to 753
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   INPUT:image           754 non-null    object
#  1   OUTPUT:result         754 non-null    object
#  2   ASSIGNMENT:worker_id  754 non-null    object
# dtypes: object(3)
# memory usage: 17.8+ KB

# %%
de = read_excel('roadSigns.xlsx')

# %%
de.head()
# Out:
#                                          INPUT:image INPUT:label  \
# 0  http://sdcimages.s3.yandex.net/nirvana/6c98f05...  pedestrian
# 1  http://sdcimages.s3.yandex.net/nirvana/d507cb6...  pedestrian
# 2  http://sdcimages.s3.yandex.net/nirvana/3aeab98...  pedestrian
# 3  http://sdcimages.s3.yandex.net/nirvana/1b4d74a...  pedestrian
# 4  http://sdcimages.s3.yandex.net/nirvana/31e2681...  pedestrian
#
#    INPUT:task-id
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5

# %%
#pd.merge(df, de, on=['INPUT:image'], how='inner').to_csv('1111.csv', sep="\t", index=False)

# %%
df_result = pd.merge(df, de, on=['INPUT:image'], how='inner')
df_result
# Out:
#                                            INPUT:image OUTPUT:result  \
# 0    http://sdcimages.s3.yandex.net/nirvana/5868dfc...    pedestrian
# 1    http://sdcimages.s3.yandex.net/nirvana/5868dfc...       no_stop
# 2    http://sdcimages.s3.yandex.net/nirvana/5868dfc...       no_stop
# 3    http://sdcimages.s3.yandex.net/nirvana/84d7947...    pedestrian
# 4    http://sdcimages.s3.yandex.net/nirvana/84d7947...       no_stop
# ..                                                 ...           ...
# 749  http://sdcimages.s3.yandex.net/nirvana/a32a065...       no_stop
# 750  http://sdcimages.s3.yandex.net/nirvana/a32a065...       no_stop
# 751  http://sdcimages.s3.yandex.net/nirvana/f1917f0...      bus_stop
# 752  http://sdcimages.s3.yandex.net/nirvana/f1917f0...      bus_stop
# 753  http://sdcimages.s3.yandex.net/nirvana/f1917f0...      bus_stop
#
#                  ASSIGNMENT:worker_id INPUT:label  INPUT:task-id
# 0    040267dc3213d9bb136605f74e9fd81f     no_stop            131
# 1    419c035390638e54057fefdb02dd2814     no_stop            131
# 2    8179b955d7706457ac3698566f59d9cf     no_stop            131
# 3    040267dc3213d9bb136605f74e9fd81f     no_stop            137
# 4    419c035390638e54057fefdb02dd2814     no_stop            137
# ..                                ...         ...            ...
# 749  1442435d91d56394f486ded242b61332     no_stop            104
# 750  9525a461cb742096fe0b0f2bd0c89cd9     no_stop            104
# 751  8c54a484fc400b6ba9e7933791b9a4ed    bus_stop             57
# 752  1442435d91d56394f486ded242b61332    bus_stop             57
# 753  80e85325f66d6bb02a3fbc25d5904d86    bus_stop             57
#
# [754 rows x 5 columns]

# %%
#Создаю столбец с подсчетом ошибок
df_result = df_result.fillna(0)
def f(row):
    if row['INPUT:label'] == row['OUTPUT:result']:
        val = 0
    else:
        val = 1
    return val
df_result['result'] = df_result.apply(f, axis=1)

# %%
df_result
# Out:
#                                            INPUT:image OUTPUT:result  \
# 0    http://sdcimages.s3.yandex.net/nirvana/5868dfc...    pedestrian
# 1    http://sdcimages.s3.yandex.net/nirvana/5868dfc...       no_stop
# 2    http://sdcimages.s3.yandex.net/nirvana/5868dfc...       no_stop
# 3    http://sdcimages.s3.yandex.net/nirvana/84d7947...    pedestrian
# 4    http://sdcimages.s3.yandex.net/nirvana/84d7947...       no_stop
# ..                                                 ...           ...
# 749  http://sdcimages.s3.yandex.net/nirvana/a32a065...       no_stop
# 750  http://sdcimages.s3.yandex.net/nirvana/a32a065...       no_stop
# 751  http://sdcimages.s3.yandex.net/nirvana/f1917f0...      bus_stop
# 752  http://sdcimages.s3.yandex.net/nirvana/f1917f0...      bus_stop
# 753  http://sdcimages.s3.yandex.net/nirvana/f1917f0...      bus_stop
#
#                  ASSIGNMENT:worker_id INPUT:label  INPUT:task-id  result
# 0    040267dc3213d9bb136605f74e9fd81f     no_stop            131       1
# 1    419c035390638e54057fefdb02dd2814     no_stop            131       0
# 2    8179b955d7706457ac3698566f59d9cf     no_stop            131       0
# 3    040267dc3213d9bb136605f74e9fd81f     no_stop            137       1
# 4    419c035390638e54057fefdb02dd2814     no_stop            137       0
# ..                                ...         ...            ...     ...
# 749  1442435d91d56394f486ded242b61332     no_stop            104       0
# 750  9525a461cb742096fe0b0f2bd0c89cd9     no_stop            104       0
# 751  8c54a484fc400b6ba9e7933791b9a4ed    bus_stop             57       0
# 752  1442435d91d56394f486ded242b61332    bus_stop             57       0
# 753  80e85325f66d6bb02a3fbc25d5904d86    bus_stop             57       0
#
# [754 rows x 6 columns]

# %%
print('Ошибок, %', df_result['result'].mean() * 100)

print('Верных ответов, %',  100 - df_result['result'].mean() * 100)
# Out:
# Ошибок, % 1.989389920424403
# Верных ответов, % 98.0106100795756

# %%
# объединяю таблицу, по признаку INPUTE:image, в de - это уникальный признак
pd.merge(df, de, on=['INPUT:image'], how='inner').to_csv('Res_1.csv', sep="\t", index=False)
