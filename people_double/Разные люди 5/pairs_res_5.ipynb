# %%
import pandas as pd
import numpy as np

# %%
# Результаты по Девиду Скину
df = pd.read_csv('./res_DS_3.tsv', sep='\t')

# %%
# Все голоса толокеров
df2 = pd.read_csv('./res_3.tsv', sep='\t')

# %%
# Объединяем навзание фото1 и фото2 (для уникальности)
df2 = df2.drop(columns=['GOLDEN:result', 'HINT:text', 'HINT:default_language'])
df2['names'] = df2['INPUT:name_pair_1'] + '*' + df2['INPUT:name_pair_2']
df['names'] = df['INPUT:name_pair_1'] + '*' + df['INPUT:name_pair_2']
df
# Out:
#                                       INPUT:name_pair_1  \
# 0     https://storage.yandexcloud.net/license-anti-s...
# 1     https://storage.yandexcloud.net/license-anti-s...
# 2     https://storage.yandexcloud.net/license-anti-s...
# 3     https://storage.yandexcloud.net/license-anti-s...
# 4     https://storage.yandexcloud.net/license-anti-s...
# ...                                                 ...
# 2726  https://storage.yandexcloud.net/license-anti-s...
# 2727  https://storage.yandexcloud.net/license-anti-s...
# 2728  https://storage.yandexcloud.net/license-anti-s...
# 2729  https://storage.yandexcloud.net/license-anti-s...
# 2730  https://storage.yandexcloud.net/license-anti-s...
#
#                                       INPUT:name_pair_2 OUTPUT:result  \
# 0     https://storage.yandexcloud.net/license-anti-s...           yes
# 1     https://storage.yandexcloud.net/license-anti-s...           yes
# 2     https://storage.yandexcloud.net/license-anti-s...           yes
# 3     https://storage.yandexcloud.net/license-anti-s...            no
# 4     https://storage.yandexcloud.net/license-anti-s...           yes
# ...                                                 ...           ...
# 2726  https://storage.yandexcloud.net/license-anti-s...            no
# 2727  https://storage.yandexcloud.net/license-anti-s...            no
# 2728  https://storage.yandexcloud.net/license-anti-s...            no
# 2729  https://storage.yandexcloud.net/license-anti-s...            no
# 2730  https://storage.yandexcloud.net/license-anti-s...            no
#
#      CONFIDENCE:result  Unnamed: 4  \
# 0              100.00%         NaN
# 1              100.00%         NaN
# 2              100.00%         NaN
# 3              100.00%         NaN
# 4              100.00%         NaN
# ...                ...         ...
# 2726           100.00%         NaN
# 2727           100.00%         NaN
# 2728           100.00%         NaN
# 2729           100.00%         NaN
# 2730           100.00%         NaN
#
#                                                   names
# 0     https://storage.yandexcloud.net/license-anti-s...
# 1     https://storage.yandexcloud.net/license-anti-s...
# 2     https://storage.yandexcloud.net/license-anti-s...
# 3     https://storage.yandexcloud.net/license-anti-s...
# 4     https://storage.yandexcloud.net/license-anti-s...
# ...                                                 ...
# 2726  https://storage.yandexcloud.net/license-anti-s...
# 2727  https://storage.yandexcloud.net/license-anti-s...
# 2728  https://storage.yandexcloud.net/license-anti-s...
# 2729  https://storage.yandexcloud.net/license-anti-s...
# 2730  https://storage.yandexcloud.net/license-anti-s...
#
# [2731 rows x 6 columns]

# %%
df = df.drop(columns=['INPUT:name_pair_1', 'INPUT:name_pair_2', 'Unnamed: 4'])
df[['names']].drop_duplicates()
df
# Out:
#      OUTPUT:result CONFIDENCE:result  \
# 0              yes           100.00%
# 1              yes           100.00%
# 2              yes           100.00%
# 3               no           100.00%
# 4              yes           100.00%
# ...            ...               ...
# 2726            no           100.00%
# 2727            no           100.00%
# 2728            no           100.00%
# 2729            no           100.00%
# 2730            no           100.00%
#
#                                                   names
# 0     https://storage.yandexcloud.net/license-anti-s...
# 1     https://storage.yandexcloud.net/license-anti-s...
# 2     https://storage.yandexcloud.net/license-anti-s...
# 3     https://storage.yandexcloud.net/license-anti-s...
# 4     https://storage.yandexcloud.net/license-anti-s...
# ...                                                 ...
# 2726  https://storage.yandexcloud.net/license-anti-s...
# 2727  https://storage.yandexcloud.net/license-anti-s...
# 2728  https://storage.yandexcloud.net/license-anti-s...
# 2729  https://storage.yandexcloud.net/license-anti-s...
# 2730  https://storage.yandexcloud.net/license-anti-s...
#
# [2731 rows x 3 columns]

# %%
df3 = df2[['names']].drop_duplicates()

# %%
# К голосам толокеров добавляем оценку по Девиду Скину
df3.dropna()
df3 = pd.merge(df, df3, on=['names'], how='inner')
df
# Out:
#      OUTPUT:result CONFIDENCE:result  \
# 0              yes           100.00%
# 1              yes           100.00%
# 2              yes           100.00%
# 3               no           100.00%
# 4              yes           100.00%
# ...            ...               ...
# 2726            no           100.00%
# 2727            no           100.00%
# 2728            no           100.00%
# 2729            no           100.00%
# 2730            no           100.00%
#
#                                                   names
# 0     https://storage.yandexcloud.net/license-anti-s...
# 1     https://storage.yandexcloud.net/license-anti-s...
# 2     https://storage.yandexcloud.net/license-anti-s...
# 3     https://storage.yandexcloud.net/license-anti-s...
# 4     https://storage.yandexcloud.net/license-anti-s...
# ...                                                 ...
# 2726  https://storage.yandexcloud.net/license-anti-s...
# 2727  https://storage.yandexcloud.net/license-anti-s...
# 2728  https://storage.yandexcloud.net/license-anti-s...
# 2729  https://storage.yandexcloud.net/license-anti-s...
# 2730  https://storage.yandexcloud.net/license-anti-s...
#
# [2731 rows x 3 columns]

# %%
df3
# Out:
#      OUTPUT:result CONFIDENCE:result  \
# 0               no           100.00%
# 1               no           100.00%
# 2               no            99.99%
# 3               no           100.00%
# 4               no           100.00%
# ...            ...               ...
# 2704            no           100.00%
# 2705            no           100.00%
# 2706            no           100.00%
# 2707            no           100.00%
# 2708            no           100.00%
#
#                                                   names
# 0     https://storage.yandexcloud.net/license-anti-s...
# 1     https://storage.yandexcloud.net/license-anti-s...
# 2     https://storage.yandexcloud.net/license-anti-s...
# 3     https://storage.yandexcloud.net/license-anti-s...
# 4     https://storage.yandexcloud.net/license-anti-s...
# ...                                                 ...
# 2704  https://storage.yandexcloud.net/license-anti-s...
# 2705  https://storage.yandexcloud.net/license-anti-s...
# 2706  https://storage.yandexcloud.net/license-anti-s...
# 2707  https://storage.yandexcloud.net/license-anti-s...
# 2708  https://storage.yandexcloud.net/license-anti-s...
#
# [2709 rows x 3 columns]

# %%
#Считаем ответивших "Yes" по каждой таске
x =df2['names'][df2['OUTPUT:result']=='yes'].value_counts()

# %%
df3['tolokers_Yes'] = df2['names'].map(x)

# %%
df3
# Out:
#      OUTPUT:result CONFIDENCE:result  \
# 0               no           100.00%
# 1               no           100.00%
# 2               no            99.99%
# 3               no           100.00%
# 4               no           100.00%
# ...            ...               ...
# 2704            no           100.00%
# 2705            no           100.00%
# 2706            no           100.00%
# 2707            no           100.00%
# 2708            no           100.00%
#
#                                                   names  tolokers_Yes
# 0     https://storage.yandexcloud.net/license-anti-s...           NaN
# 1     https://storage.yandexcloud.net/license-anti-s...           NaN
# 2     https://storage.yandexcloud.net/license-anti-s...           NaN
# 3     https://storage.yandexcloud.net/license-anti-s...           1.0
# 4     https://storage.yandexcloud.net/license-anti-s...           NaN
# ...                                                 ...           ...
# 2704  https://storage.yandexcloud.net/license-anti-s...           1.0
# 2705  https://storage.yandexcloud.net/license-anti-s...           NaN
# 2706  https://storage.yandexcloud.net/license-anti-s...           1.0
# 2707  https://storage.yandexcloud.net/license-anti-s...           NaN
# 2708  https://storage.yandexcloud.net/license-anti-s...           NaN
#
# [2709 rows x 4 columns]

# %%
df3 = df3[(df3['tolokers_Yes'] <= 7.0)]

# %%
df3 = df3[(df3['tolokers_Yes'] >= 3.0)]

# %%
df.drop_duplicates(['names'])
df3
# Out:
#      OUTPUT:result CONFIDENCE:result  \
# 11             yes            90.26%
# 14              no            99.99%
# 18              no           100.00%
# 21             yes            98.52%
# 23              no           100.00%
# ...            ...               ...
# 2387            no           100.00%
# 2413            no           100.00%
# 2432            no           100.00%
# 2457            no           100.00%
# 2597            no           100.00%
#
#                                                   names  tolokers_Yes
# 11    https://storage.yandexcloud.net/license-anti-s...           4.0
# 14    https://storage.yandexcloud.net/license-anti-s...           3.0
# 18    https://storage.yandexcloud.net/license-anti-s...           3.0
# 21    https://storage.yandexcloud.net/license-anti-s...           5.0
# 23    https://storage.yandexcloud.net/license-anti-s...           4.0
# ...                                                 ...           ...
# 2387  https://storage.yandexcloud.net/license-anti-s...           3.0
# 2413  https://storage.yandexcloud.net/license-anti-s...           3.0
# 2432  https://storage.yandexcloud.net/license-anti-s...           3.0
# 2457  https://storage.yandexcloud.net/license-anti-s...           3.0
# 2597  https://storage.yandexcloud.net/license-anti-s...           3.0
#
# [212 rows x 4 columns]

# %%
# Отбираем, где по Девиду Скину ответ дубликат
#df3 = df3[(df3['OUTPUT:result'] == 'yes')]

# %%
df3['INPUT:name_pair_1']=df3['names'].str.split('*').str.get(0)
df3['INPUT:name_pair_2']=df3['names'].str.split('*').str.get(1)

# %%
df3.to_excel('./T_yes.xlsx',  index= False)
