# %%
import pandas as pd
import numpy as np

# %%
# Результаты по Девиду Скину
df = pd.read_csv('./res_DS_4.tsv', sep='\t')

# %%
# Все голоса толокеров
df2 = pd.read_csv('./res_4.tsv', sep='\t')

# %%
# Объединяем навзание фото1 и фото2 (для уникальности)
df2 = df2.drop(columns=['GOLDEN:result', 'HINT:text', 'HINT:default_language'])
df2['names'] = df2['INPUT:name_pair_1'] + '*' + df2['INPUT:name_pair_2']
df['names'] = df['INPUT:name_pair_1'] + '*' + df['INPUT:name_pair_2']
df
# Out:
#                                      INPUT:name_pair_1  \
# 0    https://storage.yandexcloud.net/license-anti-s...
# 1    https://storage.yandexcloud.net/license-anti-s...
# 2    https://storage.yandexcloud.net/license-anti-s...
# 3    https://storage.yandexcloud.net/license-anti-s...
# 4    https://storage.yandexcloud.net/license-anti-s...
# ..                                                 ...
# 224  https://storage.yandexcloud.net/license-anti-s...
# 225  https://storage.yandexcloud.net/license-anti-s...
# 226  https://storage.yandexcloud.net/license-anti-s...
# 227  https://storage.yandexcloud.net/license-anti-s...
# 228  https://storage.yandexcloud.net/license-anti-s...
#
#                                      INPUT:name_pair_2 OUTPUT:result  \
# 0    https://storage.yandexcloud.net/license-anti-s...           yes
# 1    https://storage.yandexcloud.net/license-anti-s...           yes
# 2    https://storage.yandexcloud.net/license-anti-s...            no
# 3    https://storage.yandexcloud.net/license-anti-s...            no
# 4    https://storage.yandexcloud.net/license-anti-s...           yes
# ..                                                 ...           ...
# 224  https://storage.yandexcloud.net/license-anti-s...            no
# 225  https://storage.yandexcloud.net/license-anti-s...            no
# 226  https://storage.yandexcloud.net/license-anti-s...            no
# 227  https://storage.yandexcloud.net/license-anti-s...            no
# 228  https://storage.yandexcloud.net/license-anti-s...            no
#
#     CONFIDENCE:result  Unnamed: 4  \
# 0             100.00%         NaN
# 1             100.00%         NaN
# 2             100.00%         NaN
# 3             100.00%         NaN
# 4             100.00%         NaN
# ..                ...         ...
# 224           100.00%         NaN
# 225           100.00%         NaN
# 226           100.00%         NaN
# 227           100.00%         NaN
# 228           100.00%         NaN
#
#                                                  names
# 0    https://storage.yandexcloud.net/license-anti-s...
# 1    https://storage.yandexcloud.net/license-anti-s...
# 2    https://storage.yandexcloud.net/license-anti-s...
# 3    https://storage.yandexcloud.net/license-anti-s...
# 4    https://storage.yandexcloud.net/license-anti-s...
# ..                                                 ...
# 224  https://storage.yandexcloud.net/license-anti-s...
# 225  https://storage.yandexcloud.net/license-anti-s...
# 226  https://storage.yandexcloud.net/license-anti-s...
# 227  https://storage.yandexcloud.net/license-anti-s...
# 228  https://storage.yandexcloud.net/license-anti-s...
#
# [229 rows x 6 columns]

# %%
df = df.drop(columns=['INPUT:name_pair_1', 'INPUT:name_pair_2', 'Unnamed: 4'])
df[['names']].drop_duplicates()
df
# Out:
#     OUTPUT:result CONFIDENCE:result  \
# 0             yes           100.00%
# 1             yes           100.00%
# 2              no           100.00%
# 3              no           100.00%
# 4             yes           100.00%
# ..            ...               ...
# 224            no           100.00%
# 225            no           100.00%
# 226            no           100.00%
# 227            no           100.00%
# 228            no           100.00%
#
#                                                  names
# 0    https://storage.yandexcloud.net/license-anti-s...
# 1    https://storage.yandexcloud.net/license-anti-s...
# 2    https://storage.yandexcloud.net/license-anti-s...
# 3    https://storage.yandexcloud.net/license-anti-s...
# 4    https://storage.yandexcloud.net/license-anti-s...
# ..                                                 ...
# 224  https://storage.yandexcloud.net/license-anti-s...
# 225  https://storage.yandexcloud.net/license-anti-s...
# 226  https://storage.yandexcloud.net/license-anti-s...
# 227  https://storage.yandexcloud.net/license-anti-s...
# 228  https://storage.yandexcloud.net/license-anti-s...
#
# [229 rows x 3 columns]

# %%
df3 = df2[['names']].drop_duplicates()

# %%
# К голосам толокеров добавляем оценку по Девиду Скину
df3.dropna()
df3 = pd.merge(df, df3, on=['names'], how='inner')
df
# Out:
#     OUTPUT:result CONFIDENCE:result  \
# 0             yes           100.00%
# 1             yes           100.00%
# 2              no           100.00%
# 3              no           100.00%
# 4             yes           100.00%
# ..            ...               ...
# 224            no           100.00%
# 225            no           100.00%
# 226            no           100.00%
# 227            no           100.00%
# 228            no           100.00%
#
#                                                  names
# 0    https://storage.yandexcloud.net/license-anti-s...
# 1    https://storage.yandexcloud.net/license-anti-s...
# 2    https://storage.yandexcloud.net/license-anti-s...
# 3    https://storage.yandexcloud.net/license-anti-s...
# 4    https://storage.yandexcloud.net/license-anti-s...
# ..                                                 ...
# 224  https://storage.yandexcloud.net/license-anti-s...
# 225  https://storage.yandexcloud.net/license-anti-s...
# 226  https://storage.yandexcloud.net/license-anti-s...
# 227  https://storage.yandexcloud.net/license-anti-s...
# 228  https://storage.yandexcloud.net/license-anti-s...
#
# [229 rows x 3 columns]

# %%
df3
# Out:
#     OUTPUT:result CONFIDENCE:result  \
# 0              no           100.00%
# 1              no           100.00%
# 2              no           100.00%
# 3              no           100.00%
# 4              no           100.00%
# ..            ...               ...
# 211            no           100.00%
# 212            no           100.00%
# 213            no           100.00%
# 214            no           100.00%
# 215            no           100.00%
#
#                                                  names
# 0    https://storage.yandexcloud.net/license-anti-s...
# 1    https://storage.yandexcloud.net/license-anti-s...
# 2    https://storage.yandexcloud.net/license-anti-s...
# 3    https://storage.yandexcloud.net/license-anti-s...
# 4    https://storage.yandexcloud.net/license-anti-s...
# ..                                                 ...
# 211  https://storage.yandexcloud.net/license-anti-s...
# 212  https://storage.yandexcloud.net/license-anti-s...
# 213  https://storage.yandexcloud.net/license-anti-s...
# 214  https://storage.yandexcloud.net/license-anti-s...
# 215  https://storage.yandexcloud.net/license-anti-s...
#
# [216 rows x 3 columns]

# %%
#Считаем ответивших "Yes" по каждой таске
x =df2['names'][df2['OUTPUT:result']=='yes'].value_counts()

# %%
df3['tolokers_Yes'] = df2['names'].map(x)

# %%
#df3 = df3[(df3['tolokers_Yes'] <= 7.0)]

# %%
#df3 = df3[(df3['tolokers_Yes'] >= 3.0)]

# %%
#df.drop_duplicates(['names'])
df3
# Out:
#     OUTPUT:result CONFIDENCE:result  \
# 0              no           100.00%
# 1              no           100.00%
# 2              no           100.00%
# 3              no           100.00%
# 4              no           100.00%
# ..            ...               ...
# 211            no           100.00%
# 212            no           100.00%
# 213            no           100.00%
# 214            no           100.00%
# 215            no           100.00%
#
#                                                  names  tolokers_Yes
# 0    https://storage.yandexcloud.net/license-anti-s...           NaN
# 1    https://storage.yandexcloud.net/license-anti-s...           1.0
# 2    https://storage.yandexcloud.net/license-anti-s...           NaN
# 3    https://storage.yandexcloud.net/license-anti-s...           NaN
# 4    https://storage.yandexcloud.net/license-anti-s...           NaN
# ..                                                 ...           ...
# 211  https://storage.yandexcloud.net/license-anti-s...           NaN
# 212  https://storage.yandexcloud.net/license-anti-s...           NaN
# 213  https://storage.yandexcloud.net/license-anti-s...           NaN
# 214  https://storage.yandexcloud.net/license-anti-s...           1.0
# 215  https://storage.yandexcloud.net/license-anti-s...           5.0
#
# [216 rows x 4 columns]

# %%
# Отбираем, где по Девиду Скину ответ дубликат
#df3 = df3[(df3['OUTPUT:result'] == 'yes')]

# %%
df3['INPUT:name_pair_1']=df3['names'].str.split('*').str.get(0)
df3['INPUT:name_pair_2']=df3['names'].str.split('*').str.get(1)

# %%
df3.to_excel('./T_yes_4.xlsx',  index= False)
