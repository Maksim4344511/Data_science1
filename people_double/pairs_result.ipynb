# %%
import pandas as pd
import numpy as np

# %%
# Результаты по Девиду Скину
df = pd.read_csv('./res_DS.tsv', sep='\t')

# %%
# Все голоса толокеров
df2 = pd.read_csv('./res_1.tsv', sep='\t')

# %%
# Объединяем навзание фото1 и фото2 (для уникальности)
df2 = df2.drop(columns=['GOLDEN:result', 'HINT:text', 'HINT:default_language'])
df2['names'] = df2['INPUT:name_pair_1'] + '*' + df2['INPUT:name_pair_2']
df['names'] = df['INPUT:name_pair_1'] + '*' + df['INPUT:name_pair_2']

# %%
df = df.drop(columns=['INPUT:name_pair_1', 'INPUT:name_pair_2', 'Unnamed: 4'])

# %%
df3 = df2[['names']].drop_duplicates()

# %%
# К голосам толокеров добавляем оценку по Девиду Скину
df3.dropna()
df3 = pd.merge(df, df3, on=['names'], how='inner')

# %%
df3
# Out:
#     OUTPUT:result CONFIDENCE:result  \
# 0              no           100.00%
# 1              no           100.00%
# 2             yes           100.00%
# 3             yes           100.00%
# 4              no           100.00%
# ..            ...               ...
# 987            no           100.00%
# 988            no            99.99%
# 989           yes            99.99%
# 990            no            99.98%
# 991           yes            99.99%
#
#                                                  names
# 0    https://storage.yandexcloud.net/license-anti-s...
# 1    https://storage.yandexcloud.net/license-anti-s...
# 2    https://storage.yandexcloud.net/license-anti-s...
# 3    https://storage.yandexcloud.net/license-anti-s...
# 4    https://storage.yandexcloud.net/license-anti-s...
# ..                                                 ...
# 987  https://storage.yandexcloud.net/license-anti-s...
# 988  https://storage.yandexcloud.net/license-anti-s...
# 989  https://storage.yandexcloud.net/license-anti-s...
# 990  https://storage.yandexcloud.net/license-anti-s...
# 991  https://storage.yandexcloud.net/license-anti-s...
#
# [992 rows x 3 columns]

# %%
#Считаем ответивших "Yes" по каждой таске
x =df2['names'][df2['OUTPUT:result']=='yes'].value_counts()

# %%
df3['tolokers_Yes'] = df2['names'].map(x)

# %%
df3
# Out:
#     OUTPUT:result CONFIDENCE:result  \
# 0              no           100.00%
# 1              no           100.00%
# 2             yes           100.00%
# 3             yes           100.00%
# 4              no           100.00%
# ..            ...               ...
# 987            no           100.00%
# 988            no            99.99%
# 989           yes            99.99%
# 990            no            99.98%
# 991           yes            99.99%
#
#                                                  names  tolokers_Yes
# 0    https://storage.yandexcloud.net/license-anti-s...           8.0
# 1    https://storage.yandexcloud.net/license-anti-s...           9.0
# 2    https://storage.yandexcloud.net/license-anti-s...           NaN
# 3    https://storage.yandexcloud.net/license-anti-s...           5.0
# 4    https://storage.yandexcloud.net/license-anti-s...           8.0
# ..                                                 ...           ...
# 987  https://storage.yandexcloud.net/license-anti-s...           NaN
# 988  https://storage.yandexcloud.net/license-anti-s...           3.0
# 989  https://storage.yandexcloud.net/license-anti-s...           1.0
# 990  https://storage.yandexcloud.net/license-anti-s...           7.0
# 991  https://storage.yandexcloud.net/license-anti-s...          10.0
#
# [992 rows x 4 columns]

# %%
df3 = df3[(df3['tolokers_Yes'] <= 7.0)]

# %%
df3 = df3[(df3['tolokers_Yes'] >= 3.0)]

# %%
df3
# Out:
#     OUTPUT:result CONFIDENCE:result  \
# 3             yes           100.00%
# 6             yes           100.00%
# 27            yes           100.00%
# 28             no           100.00%
# 32            yes           100.00%
# ..            ...               ...
# 944            no            99.99%
# 957           yes           100.00%
# 963            no            99.97%
# 988            no            99.99%
# 990            no            99.98%
#
#                                                  names  tolokers_Yes
# 3    https://storage.yandexcloud.net/license-anti-s...           5.0
# 6    https://storage.yandexcloud.net/license-anti-s...           6.0
# 27   https://storage.yandexcloud.net/license-anti-s...           4.0
# 28   https://storage.yandexcloud.net/license-anti-s...           5.0
# 32   https://storage.yandexcloud.net/license-anti-s...           3.0
# ..                                                 ...           ...
# 944  https://storage.yandexcloud.net/license-anti-s...           7.0
# 957  https://storage.yandexcloud.net/license-anti-s...           6.0
# 963  https://storage.yandexcloud.net/license-anti-s...           6.0
# 988  https://storage.yandexcloud.net/license-anti-s...           3.0
# 990  https://storage.yandexcloud.net/license-anti-s...           7.0
#
# [135 rows x 4 columns]

# %%
# Отбираем, где по Девиду Скину ответ дубликат
df3 = df3[(df3['OUTPUT:result'] == 'yes')]
df3
# Out:
#     OUTPUT:result CONFIDENCE:result  \
# 3             yes           100.00%
# 6             yes           100.00%
# 27            yes           100.00%
# 32            yes           100.00%
# 40            yes            99.99%
# 94            yes           100.00%
# 114           yes            99.99%
# 123           yes           100.00%
# 144           yes           100.00%
# 162           yes           100.00%
# 205           yes           100.00%
# 207           yes            99.99%
# 210           yes           100.00%
# 219           yes            99.99%
# 225           yes           100.00%
# 275           yes            99.99%
# 302           yes           100.00%
# 321           yes           100.00%
# 322           yes            99.99%
# 348           yes            99.97%
# 362           yes           100.00%
# 372           yes           100.00%
# 397           yes            99.99%
# 438           yes           100.00%
# 454           yes           100.00%
# 500           yes           100.00%
# 508           yes            99.99%
# 512           yes           100.00%
# 532           yes            99.99%
# 554           yes           100.00%
# 582           yes            99.99%
# 590           yes           100.00%
# 619           yes           100.00%
# 631           yes            99.99%
# 656           yes           100.00%
# 680           yes            99.98%
# 692           yes           100.00%
# 697           yes           100.00%
# 717           yes            99.99%
# 742           yes           100.00%
# 747           yes           100.00%
# 813           yes           100.00%
# 860           yes            99.99%
# 893           yes           100.00%
# 894           yes            99.70%
# 905           yes            99.99%
# 915           yes            99.99%
# 920           yes            99.99%
# 938           yes            99.99%
# 957           yes           100.00%
#
#                                                  names  tolokers_Yes
# 3    https://storage.yandexcloud.net/license-anti-s...           5.0
# 6    https://storage.yandexcloud.net/license-anti-s...           6.0
# 27   https://storage.yandexcloud.net/license-anti-s...           4.0
# 32   https://storage.yandexcloud.net/license-anti-s...           3.0
# 40   https://storage.yandexcloud.net/license-anti-s...           6.0
# 94   https://storage.yandexcloud.net/license-anti-s...           5.0
# 114  https://storage.yandexcloud.net/license-anti-s...           6.0
# 123  https://storage.yandexcloud.net/license-anti-s...           7.0
# 144  https://storage.yandexcloud.net/license-anti-s...           6.0
# 162  https://storage.yandexcloud.net/license-anti-s...           7.0
# 205  https://storage.yandexcloud.net/license-anti-s...           3.0
# 207  https://storage.yandexcloud.net/license-anti-s...           4.0
# 210  https://storage.yandexcloud.net/license-anti-s...           5.0
# 219  https://storage.yandexcloud.net/license-anti-s...           4.0
# 225  https://storage.yandexcloud.net/license-anti-s...           7.0
# 275  https://storage.yandexcloud.net/license-anti-s...           7.0
# 302  https://storage.yandexcloud.net/license-anti-s...           5.0
# 321  https://storage.yandexcloud.net/license-anti-s...           5.0
# 322  https://storage.yandexcloud.net/license-anti-s...           7.0
# 348  https://storage.yandexcloud.net/license-anti-s...           4.0
# 362  https://storage.yandexcloud.net/license-anti-s...           4.0
# 372  https://storage.yandexcloud.net/license-anti-s...           5.0
# 397  https://storage.yandexcloud.net/license-anti-s...           6.0
# 438  https://storage.yandexcloud.net/license-anti-s...           3.0
# 454  https://storage.yandexcloud.net/license-anti-s...           6.0
# 500  https://storage.yandexcloud.net/license-anti-s...           3.0
# 508  https://storage.yandexcloud.net/license-anti-s...           4.0
# 512  https://storage.yandexcloud.net/license-anti-s...           3.0
# 532  https://storage.yandexcloud.net/license-anti-s...           5.0
# 554  https://storage.yandexcloud.net/license-anti-s...           3.0
# 582  https://storage.yandexcloud.net/license-anti-s...           5.0
# 590  https://storage.yandexcloud.net/license-anti-s...           4.0
# 619  https://storage.yandexcloud.net/license-anti-s...           7.0
# 631  https://storage.yandexcloud.net/license-anti-s...           5.0
# 656  https://storage.yandexcloud.net/license-anti-s...           7.0
# 680  https://storage.yandexcloud.net/license-anti-s...           3.0
# 692  https://storage.yandexcloud.net/license-anti-s...           6.0
# 697  https://storage.yandexcloud.net/license-anti-s...           5.0
# 717  https://storage.yandexcloud.net/license-anti-s...           6.0
# 742  https://storage.yandexcloud.net/license-anti-s...           5.0
# 747  https://storage.yandexcloud.net/license-anti-s...           5.0
# 813  https://storage.yandexcloud.net/license-anti-s...           7.0
# 860  https://storage.yandexcloud.net/license-anti-s...           7.0
# 893  https://storage.yandexcloud.net/license-anti-s...           7.0
# 894  https://storage.yandexcloud.net/license-anti-s...           7.0
# 905  https://storage.yandexcloud.net/license-anti-s...           6.0
# 915  https://storage.yandexcloud.net/license-anti-s...           7.0
# 920  https://storage.yandexcloud.net/license-anti-s...           6.0
# 938  https://storage.yandexcloud.net/license-anti-s...           7.0
# 957  https://storage.yandexcloud.net/license-anti-s...           6.0

# %%
df3['INPUT:name_pair_1']=df3['names'].str.split('*').str.get(0)
df3['INPUT:name_pair_2']=df3['names'].str.split('*').str.get(1)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1116\902398385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['INPUT:name_pair_1']=df3['names'].str.split('*').str.get(0)
# C:\Users\user\AppData\Local\Temp\ipykernel_1116\902398385.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['INPUT:name_pair_2']=df3['names'].str.split('*').str.get(1)

# %%
#df3.to_excel('./T3.xlsx',  index= False)

# %%
#Пробую еще раз
#Пробую еще раз
df5 = pd.read_csv('./res_1.tsv', sep='\t')

# %%
df5['names']  = df5['INPUT:name_pair_1'] + '*' + df5['INPUT:name_pair_2']

# %%
x = df5['names'][df5['OUTPUT:result']=='yes'].value_counts() / df5['names'].value_counts()
y = df5['names'].value_counts()
df6 = df5[['names']].drop_duplicates()
df6['percent_tolokers_Yes'] = df5['names'].map(x)
df6['count_answer'] = df5['names'].map(y)

# %%
df6
# Out:
#                                                   names  percent_tolokers_Yes  \
# 0     https://storage.yandexcloud.net/license-anti-s...                   0.8
# 1     https://storage.yandexcloud.net/license-anti-s...                   0.9
# 2     https://storage.yandexcloud.net/license-anti-s...                   NaN
# 3     https://storage.yandexcloud.net/license-anti-s...                   0.5
# 4     https://storage.yandexcloud.net/license-anti-s...                   0.8
# ...                                                 ...                   ...
# 9201  https://storage.yandexcloud.net/license-anti-s...                   NaN
# 9204  https://storage.yandexcloud.net/license-anti-s...                   0.1
# 9216  https://storage.yandexcloud.net/license-anti-s...                   0.5
# 9232  https://storage.yandexcloud.net/license-anti-s...                   0.3
# 9243  https://storage.yandexcloud.net/license-anti-s...                   0.7
#
#       count_answer
# 0               10
# 1               10
# 2               10
# 3               10
# 4               10
# ...            ...
# 9201            10
# 9204            10
# 9216            10
# 9232            10
# 9243            10
#
# [974 rows x 3 columns]

# %%
df7 = df6[(df6['percent_tolokers_Yes'] >= 0.3) & (df6['percent_tolokers_Yes'] <= 0.7)]

# %%
df7
# Out:
#                                                   names  percent_tolokers_Yes  \
# 3     https://storage.yandexcloud.net/license-anti-s...                   0.5
# 6     https://storage.yandexcloud.net/license-anti-s...                   0.6
# 27    https://storage.yandexcloud.net/license-anti-s...                   0.4
# 32    https://storage.yandexcloud.net/license-anti-s...                   0.3
# 38    https://storage.yandexcloud.net/license-anti-s...                   0.7
# ...                                                 ...                   ...
# 9187  https://storage.yandexcloud.net/license-anti-s...                   0.5
# 9192  https://storage.yandexcloud.net/license-anti-s...                   0.7
# 9216  https://storage.yandexcloud.net/license-anti-s...                   0.5
# 9232  https://storage.yandexcloud.net/license-anti-s...                   0.3
# 9243  https://storage.yandexcloud.net/license-anti-s...                   0.7
#
#       count_answer
# 3               10
# 6               10
# 27              10
# 32              10
# 38              10
# ...            ...
# 9187            10
# 9192            10
# 9216            10
# 9232            10
# 9243            10
#
# [168 rows x 3 columns]
